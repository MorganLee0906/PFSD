# %%
import os
import glob

def convert_sas_to_csv(sas_file, csv_file):
    with open(sas_file, 'r', encoding='BIG5', errors='ignore') as f:
        lines = f.readlines()

    csv_numbers = []
    csv_questions = {}
    csv_answers = {}
    for i in range(len(lines)):
        if lines[i].startswith('LABEL') or lines[i].startswith('label') or lines[i].startswith('Label'):
            for j in range(i+1, len(lines)):
                lines[j] = lines[j].replace(",", "，")
                try:
                    number = lines[j].strip().replace('"', '').split('=')[0].strip()
                    question = lines[j].strip().replace('"', '').split('=')[1].strip()
                    csv_questions[number] = question
                except:
                    break
        if lines[i].startswith('format') or lines[i].startswith('FORMAT') or lines[i].startswith('Format'):
            for j in range(i+1, len(lines)):
                if lines[j].startswith('  '):
                    answers = lines[j].split(".")
                    answers.pop()
                    for a in answers:
                        csv_numbers.append(a.split()[0].strip())
                        csv_answers[a.split()[0].strip()] = a.split()[1].strip()
                else:
                    break

    dir_name = os.path.basename(os.path.dirname(sas_file))
    csv_file = os.path.join(os.path.dirname(sas_file), dir_name + '_label.csv')
    
    with open(csv_file, 'w+', encoding='utf-8') as f:
        f.write("YEAR,NUMBER,QUESTION,ANSWER\n")
        for number in csv_numbers:
            f.write(dir_name + ',' + number + ',' + csv_questions[number] + ',' + csv_answers[number] + '\n')


if __name__ == '__main__':
    data_folder = '/Users/virginialiu/Desktop/cclab/PSFD/data/主樣本或'
    for subdir in os.listdir(data_folder):
        subdir_path = os.path.join(data_folder, subdir)
        if os.path.isdir(subdir_path):
            sas_files = glob.glob(os.path.join(subdir_path, '*.sas'))
            for sas_file in sas_files:
                convert_sas_to_csv(sas_file, '')
                print(subdir)
# Out:
# RCI2014
# RCI2009
# RCI2009
# RCI2007
# RCI2011
# RCI2016
# RCI2018
# RCI2005
# RCI2004

# %%
#讀檔
import pandas as pd
dfCI2001 = pd.read_csv('/Users/virginialiu/Desktop/cclab/PSFD/complete/CI2002/cii2002_prog_v201401_label.csv')

dfCI2001.head()
# Out:
#      x04                問卷編號
# 0    x10           受訪者與戶長之關係
# 1  card3                  卡三
# 2    a01                  性別
# 3    a02  請問您是在哪一年出生的?民國____
# 4  a03z1           請問您的出生地是:

# %%
#單檔案讀：RR2012
def convert_sas_to_csv(sas_file, csv_file):
    with open(sas_file, 'r', encoding='BIG5', errors='ignore') as f:
        lines = f.readlines()

    csv_numbers = []
    csv_questions = {}
    csv_answers = {}
    for i in range(len(lines)):
        if lines[i].startswith('LABEL') or lines[i].startswith('label') or lines[i].startswith('Label'):
            for j in range(i+1, len(lines)):
                lines[j] = lines[j].replace(",", "，")
                try:
                    number = lines[j].strip().replace('"', '').split('=')[0].strip()
                    question = lines[j].strip().replace('"', '').split('=')[1].strip()
                    csv_questions[number] = question
                except:
                    break
        if lines[i].startswith('format') or lines[i].startswith('FORMAT') or lines[i].startswith('Format'):
            for j in range(i+1, len(lines)):
                if lines[j].startswith('run')!=1:
                    answers = lines[j].split(".")
                    answers.pop()
                    for a in answers:
                        csv_numbers.append(a.split()[0].strip())
                        csv_answers[a.split()[0].strip()] = a.split()[1].strip()
                else:
                    break
    with open(csv_file, 'w+', encoding='utf-8') as f:
        f.write("YEAR,NUMBER,QUESTION,ANSWER\n")
        for number in csv_numbers:
            #print(number)
            #print(csv_questions[number])
            #print(csv_answers[number])
            try:
                f.write("RR2012" + ',' + number + ',' + csv_questions[number] + ',' + csv_answers[number] + '\n')
            except:
                f.write('\n')
                f.write('\n')
                f.write('\n')
                f.write('\n')
                f.write('\n')
                f.write('\n')

if __name__ == '__main__':
    sas_file = '/Users/virginialiu/Desktop/cclab/PSFD/data/主樣本/RR2012/rr2012_prog_v201605.sas'
    csv_file = '/Users/virginialiu/Desktop/cclab/PSFD/data/主樣本/RR2012/RR2012_label.csv'
    convert_sas_to_csv(sas_file, csv_file)

# %%
#單檔案讀：RR2018
def convert_sas_to_csv(sas_file, csv_file):
    with open(sas_file, 'r', encoding='BIG5', errors='ignore') as f:
        lines = f.readlines()

    csv_numbers = []
    csv_questions = {}
    csv_answers = {}
    for i in range(len(lines)):
        if lines[i].startswith('LABEL') or lines[i].startswith('label') or lines[i].startswith('Label'):
            for j in range(i+1, len(lines)):
                lines[j] = lines[j].replace(",", "，")
                try:
                    number = lines[j].strip().replace('"', '').split('=')[0].strip()
                    question = lines[j].strip().replace('"', '').split('=')[1].strip()
                    csv_questions[number] = question
                except:
                    break
        if lines[i].startswith('FORMAT'):
            for j in range(i+1, len(lines)):
                if lines[j].startswith('run')!=1:
                    answers = lines[j].split(".")
                    answers.pop()
                    for a in answers:
                        csv_numbers.append(a.split()[0].strip())
                        csv_answers[a.split()[0].strip()] = a.split()[1].strip()
                else:
                    break
    with open(csv_file, 'w+', encoding='utf-8') as f:
        f.write("YEAR,NUMBER,QUESTION,ANSWER\n")
        for number in csv_numbers:
            #print(number)
            #print(csv_questions[number])
            #print(csv_answers[number])
            try:
                f.write("RR2012" + ',' + number + ',' + csv_questions[number] + ',' + csv_answers[number] + '\n')
            except:
                f.write('\n')
                f.write('\n')
                f.write('\n')
                f.write('\n')
                f.write('\n')
                f.write('\n')

if __name__ == '__main__':
    sas_file = '/Users/virginialiu/Desktop/cclab/PSFD/data/主樣本/RR2018/RR2018_prog_v201907.sas'
    csv_file = '/Users/virginialiu/Desktop/cclab/PSFD/data/主樣本/RR2018/RR2018_label.csv'
    convert_sas_to_csv(sas_file, csv_file)

# %%
#單檔案讀：CVII2012
import os
import glob
def convert_sas_to_csv(sas_file, csv_file):
    with open(sas_file, 'r', encoding='BIG5', errors='ignore') as f:
        lines = f.readlines()

    csv_numbers = []
    csv_questions = {}
    csv_answers = {}
    for i in range(len(lines)):
        if lines[i].startswith('LABEL'):
            for j in range(i+1, len(lines)):
                lines[j] = lines[j].replace(",", "，")
                try:
                    number = lines[j].strip().replace('"', '').split('=')[0].strip()
                    question = lines[j].strip().replace('"', '').split('=')[1].strip()
                    csv_questions[number] = question
                except:
                    break
        if lines[i].startswith('   FORMAT'):
            for j in range(i+1, len(lines)):
                if lines[j].startswith('   '):
                    answers = lines[j].split(".")
                    answers.pop()
                    for a in answers:
                        csv_numbers.append(a.split()[0].strip())
                        csv_answers[a.split()[0].strip()] = a.split()[1].strip()
                else:
                    break

    dir_name = os.path.basename(os.path.dirname(sas_file))
    csv_file = os.path.join(os.path.dirname(sas_file), dir_name + '_label.csv')
    
    with open(csv_file, 'w+', encoding='utf-8') as f:
        f.write("YEAR,NUMBER,QUESTION,ANSWER\n")
        for number in csv_numbers:
            f.write(dir_name + ',' + number + ',' + csv_questions[number] + ',' + csv_answers[number] + '\n')

if __name__ == '__main__':
    sas_file_CVII2012 = '/Users/virginialiu/Desktop/cclab/PSFD/data/子女樣本/CVII2012/cvii2012_prog_v201606.sas'
    csv_file_CVII2012 = '/Users/virginialiu/Desktop/cclab/PSFD/data/子女樣本/CVII2012/CVII2012_label.csv'
    convert_sas_to_csv(sas_file_CVII2012, csv_file_CVII2012)

# %%
#單檔案讀：RCI2016、CIV2006、CIX2016
import os
import glob
def convert_sas_to_csv(sas_file, csv_file):
    with open(sas_file, 'r', encoding='BIG5', errors='ignore') as f:
        lines = f.readlines()

    csv_numbers = []
    csv_questions = {}
    csv_answers = {}
    for i in range(len(lines)):
        if lines[i].startswith('LABEL') or lines[i].startswith('label'):
            for j in range(i+1, len(lines)):
                lines[j] = lines[j].replace(",", "，")
                try:
                    number = lines[j].strip().replace('"', '').split('=')[0].strip()
                    question = lines[j].strip().replace('"', '').split('=')[1].strip()
                    csv_questions[number] = question
                except:
                    break
        if lines[i].startswith('format'):
            for j in range(i+1, len(lines)):
                if lines[j].startswith(' '):
                    answers = lines[j].split(".")
                    answers.pop()
                    for a in answers:
                        csv_numbers.append(a.split()[0].strip())
                        csv_answers[a.split()[0].strip()] = a.split()[1].strip()
                else:
                    break

    dir_name = os.path.basename(os.path.dirname(sas_file))
    csv_file = os.path.join(os.path.dirname(sas_file), dir_name + '_label.csv')
    
    with open(csv_file, 'w+', encoding='utf-8') as f:
        f.write("YEAR,NUMBER,QUESTION,ANSWER\n")
        for number in csv_numbers:
            f.write(dir_name + ',' + number + ',' + csv_questions[number] + ',' + csv_answers[number] + '\n')

if __name__ == '__main__':
    sas_file_RCI2016 = '/Users/virginialiu/Desktop/cclab/PSFD/data/新抽樣主樣本或/RCI2016/RCI2016_prog_v201811.sas'
    csv_file_RCI2016 = '/Users/virginialiu/Desktop/cclab/PSFD/data/新抽樣主樣本或/RCI2016/RCI2016_label.csv'
    convert_sas_to_csv(sas_file_RCI2016, csv_file_RCI2016)

    sas_file_CIV2006 = '//Users/virginialiu/Desktop/cclab/PSFD/data/子女樣本/CIV2006/CIV2006_prog_v201806.sas'
    csv_file_CIV2006 = '/Users/virginialiu/Desktop/cclab/PSFD/data/子女樣本/CIV2006/CIV2006_label.csv'
    convert_sas_to_csv(sas_file_RCI2016, csv_file_RCI2016)

    sas_file_CIX2016 = '/Users/virginialiu/Desktop/cclab/PSFD/data/子女樣本/CIX2016/CIX2016_prog_v201812.sas'
    csv_file_CIX2016 = '/Users/virginialiu/Desktop/cclab/PSFD/data/子女樣本/CIX2016/CIX2016_label.csv'
    convert_sas_to_csv(sas_file_CIX2016, csv_file_CIX2016)

# %%
#單檔案讀：RR2018
import os
import glob
def convert_sas_to_csv(sas_file, csv_file):
    with open(sas_file, 'r', encoding='BIG5', errors='ignore') as f:
        lines = f.readlines()

    csv_numbers = []
    csv_questions = {}
    csv_answers = {}
    for i in range(len(lines)):
        if lines[i].startswith('LABEL'):
            for j in range(i+1, len(lines)):
                lines[j] = lines[j].replace(",", "，")
                try:
                    number = lines[j].strip().replace('"', '').split('=')[0].strip()
                    question = lines[j].strip().replace('"', '').split('=')[1].strip()
                    csv_questions[number] = question
                except:
                    break
        if lines[i].startswith('FORMAT'):
            for j in range(i+1, len(lines)):
                if lines[j].startswith('	'):
                    answers = lines[j].split(".")
                    answers.pop()
                    for a in answers:
                        csv_numbers.append(a.split()[0].strip())
                        csv_answers[a.split()[0].strip()] = a.split()[1].strip()
                else:
                    break

    dir_name = os.path.basename(os.path.dirname(sas_file))
    csv_file = os.path.join(os.path.dirname(sas_file), dir_name + '_label.csv')
    
    with open(csv_file, 'w+', encoding='utf-8') as f:
        f.write("YEAR,NUMBER,QUESTION,ANSWER\n")
        for number in csv_numbers:
            f.write(dir_name + ',' + number + ',' + csv_questions[number] + ',' + csv_answers[number] + '\n')

if __name__ == '__main__':
    sas_file_RR2018 = '/Users/virginialiu/Desktop/cclab/PSFD/data/主樣本/RR2018/RR2018_prog_v201907.sas'
    csv_file_RR2018 = '/Users/virginialiu/Desktop/cclab/PSFD/data/主樣本/RR2018/RR2018_answer.csv'
    convert_sas_to_csv(sas_file_RR2018, csv_file_RR2018)
